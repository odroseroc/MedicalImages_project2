# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

img = sitk.ReadImage("../data/raw/COMMON_images_masks/common_40_image.nii.gz")
arr = sitk.GetArrayFromImage(img)  # (z, y, x)

print("Shape (z,y,x):", arr.shape)
print("Spacing:", img.GetSpacing())

@interact(z=(0, arr.shape[0]-1))
def show_slice(z=0):
    plt.imshow(arr[z,:,:], cmap="gray")
    plt.title(f"Axial slice {z}")
    plt.axis("off")
# Out:
# Shape (z,y,x): (286, 512, 512)
# Spacing: (0.6640625, 0.6640625, 0.79998779296875)
# interactive(children=(IntSlider(value=0, description='z', max=285), Output()), _dom_classes=('widget-interact'…

# %%
@interact(y=(0, arr.shape[1]-1))
def show_slice(y=0):
    plt.imshow(arr[:,y,:], cmap="gray")
    plt.title(f"Axial slice {y}")
    plt.axis("off")
# Out:
# interactive(children=(IntSlider(value=0, description='y', max=511), Output()), _dom_classes=('widget-interact'…
